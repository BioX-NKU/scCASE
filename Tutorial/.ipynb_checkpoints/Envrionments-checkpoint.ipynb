# %%
# !python --version
# Out:
# Python 3.10.4

# %%
dependencies = ['pandas',
'scanpy',
'numpy',
'anndata',
'scikit-learn',
'louvain',
'leidenalg',
'igraph'
'episcanpy',
'kneed>=0.7.0']

# %%
# !pip list
# Out:
# Package                           Version
# --------------------------------- -------------------
# absl-py                           1.4.0
# alabaster                         0.7.12
# anndata                           0.8.0
# anndata2ri                        1.1
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              21.2.0
# asttokens                         2.0.5
# astunparse                        1.6.3
# attrs                             22.1.0
# Babel                             2.10.3
# backcall                          0.2.0
# bamnostic                         1.1.8
# bavaria                           0.0.1
# beautifulsoup4                    4.11.1
# bleach                            5.0.1
# brotlipy                          0.7.0
# cached-property                   1.5.2
# cachetools                        5.3.0
# certifi                           2022.9.24
# cffi                              1.15.1
# charset-normalizer                2.1.0
# ...
